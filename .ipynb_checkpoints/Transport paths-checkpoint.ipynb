# %% [markdown]
# # Задача об оптимальном распредлении автобусов по маршрутам
# В некотором городе с заданным взвешенным графом транспортной сети $G = (V, E, \{ t_e \}_{e \in E})$ имеются различие маршруты движения автобусов $ P $. Потоки пассажиров, приходящих на каждую из остановок, описываются независимыми пуассовновсими процессами с фиксиррованными интенсивностями $\lambda_i, i \in V $. Считайте, что пассажжиры садятся на первый подходящий автобус, не дожидаюсь следующего с другого маршрута, который может чуть быстрее доставить их в пукт назначения. Пусть $\pi_{ij}$ - доля пассажиров, направляющихся с остановки $i$ на остановку $j$, причем $\forall i, j \in V: \pi_{ij} > 0  \exists p \in P: i, j \in p$. Пусть $m_p$ - число автобусов, курсирующих по маршруту $p$. Считая $\sum_{p \in P} m_p = M$ и априорно предполагая, что $m_p >> 1$, предложите эффективный алгоритм решения задачи распределния имеющегося автобусного парка из $М$ автобусов по маршрутам так, чтобы математическое ожидание общего времени, потерянного всеми пассажирами в пути было бы минимальным.

# %% [markdown]
# Рассмотрим станцию:
# $X_i(t)$ - число пассажиров, которое набирается за время $t$ Из них едут в $j != i: \pi_{ij} \dot X_i(t)$
# $t_p = 2 \sum_{e \in p} t_e$ (все маршруты считаем кольцевыми).
# Будем считать движение автобусов Пуассоновским процессом. На маршруте $p$ $m_p$ автобусов, и они все должны проехать станцию $i \in p$ за $t_p$.
# Тогда автобусы "капают" в $i$ с интенсивностью $\frac{m_p}{t_p}$ $Y_p(t)$
# Но через $i$ проходят и автобусы других маршрутов, пассажиры которых хотят попапасть в $j$, подходят маршруты, которые содеражат вершину $j$

# %% [markdown]
# За время $t$ в $i$ придет $\sum_{i, j \in p} Y_p(t)$ таких автобусов, у каждого $Y_p(t)$ интернсивность $\frac{m_p}{t_p}$, значит сумма -Пуассновоский процесс с интенсивностью $\sum_{i, j \in p} \frac{m_p}{t_p}$. Время между скачками пуассоновского процесса имеет экспоненциальное распределение от интенсивности пуассоновского процесса. $t_{ож i j} \sim Exp(\sum_{i, j \in p} \frac{m_p}{t_p})$

# %% [markdown]
# Мат ожидание $Exp(\gamma)$ равна $\frac{1}{\gamma}$

# %% [markdown]
# Тогда рассмотрим суммарное время ожидания автобуса пассажирами на станции i. Пассажиров в час $\frac{X_i(t)}{t} * \pi_{ij}$

# %% [markdown]
# Их суммарное ожидание
# $ \sum_{j \neq i} \frac{x_i(t)}{t} \cdot \pi_{i j} \cdot tож _{i j}$
# Hа всех станциях:
# $$
# \begin{aligned}
# & T_{\text {oж }}=\sum_{i \in G} \sum_{j \neq i} \cfrac{X_i(t)}{t} \cdot \pi_{i j} \cdot t_{ож_{ij}}\\
# & \mathbb{E}\left[T_{ож}\right]=\sum_{i \in G} \sum_{j \neq i} \cfrac{\mathbb{E} X_i(t)}{t} \cdot \pi_{i j} \cdot \mathbb{\mathbb { E }}\left(t_{ож_{i j}}\right)= \\
# & =\sum_{i \in G} \sum_{j \neq i} \lambda_i \cdot \pi_{i j} \cdot \cfrac{1}{\sum\limits_{i, j \in p} \cfrac{m_p}{t_p}} \\
# &
# \end{aligned}
# $$

# %% [markdown]
# $$ Вид \; целевой\;  функции\;
#  \sum_{i \in_G} \sum_{j \neq i}  (\cfrac{A_{i j}}{\sum_{i, j \in p} \cfrac{m_p}{t_p}}+B_{i j})$$

# %% [markdown]
# $$Ограничения \; \mathbb{B}=\left\{\begin{array}{c}\sum\limits_{p \in P} m_p=M \\ m_p \geqslant 0 \quad \forall p \in P\end{array}\right.$$
# $$\mathbb{B} - симплекс:$$
# $$ \sum\limits_{p \in p} \cfrac{m_p}{М}=1 ; \cfrac{m_p}{М} \geqslant 0 \quad \forall p \in P$$
# $$3начит,\; выпуклое\; мн-во$$

# %% [markdown]
# $F\left(m_1, \ldots m_p\right)=F(\vec{m})$
# маршруты упорядочены от 1 до p
# $\vec{T_{i j}}$ - вектор, у которого координаты $\cfrac{1}{t_p}$ если $i, j \in p; 0$ - иначе$
# \Rightarrow F(\vec{m})=\sum_{i \neq j} \frac{A_{i j}}{\left(\vec{m}, \vec{T_{i j}}\right)}
# $

# %% [markdown]
# $F(\vec{m})$ - выпукла?
# если для любых $\vec{m_1}, \ \vec{m_2}$ из области определения и любых $\alpha \in [0,1]$ имеет место:
# $$F\left(\alpha \vec{m}_1+(1-\alpha) \vec{m}_2\right) \leq \alpha F\left(\vec{m}_1\right)+(1-\alpha) F\left(\vec{m_2}\right)?$$

# %% [markdown]
# $$\begin{aligned} & F\left(\alpha \vec{m}_1+(1-\alpha) \vec{m}_2\right)= \\ = & \sum_{i \neq j} \frac{A_{i j}}{\left(\alpha \vec{m}_1+(1-\alpha) \cdot \vec{m}_2, \vec{T}_{i j}\right)} \\ & \alpha F\left(\vec{m}_1\right)+(1-\alpha) F\left(\vec{m}_2\right)= \\ = & \sum_{i \neq j}\left(\frac{A_{i j} \cdot \alpha}{\left(\vec{m}_1, \vec{T}_{i j}\right)}+\frac{A_{i j} \cdot(1-\alpha)}{\left(\vec{m}_2, \vec{T}_{i j}\right)}\right)= \\ = & \sum_{i \neq j} \frac{A_{i j} \cdot\left(\alpha \cdot\left(\vec{m}_2, \vec{T}_{i j}\right)+(1-\alpha) \cdot\left(\vec{m}_1, \vec{T}_{i j}\right)\right.}{\left(\vec{m}_1 \vec{T}_{i j}\right) \cdot\left(\vec{m}_2, \vec{T}_{i j}\right)}\end{aligned}$$

# %% [markdown]
# $$Если \; \quad F\left(\alpha \vec{m}_1+(1-\alpha) m_2\right)-\alpha F\left(\vec{m}_1\right)-(1-\alpha) F\left(\vec{m}_2\right) \leq 0,\; то\; победа!$$

# %% [markdown]
# $\sum_{i \neq j} A_{i j} \cdot \cfrac{N_{i j}}{\left(\vec{m}_1, \vec{T}_{i j}\right) \cdot\left(\vec{m}_2 \cdot \vec{T}_{i j}\right) \cdot\left(\alpha \vec{m}_1+(1-\alpha) \vec{m}_2 \cdot T_{i j}\right)}$
# $N_{i j}=\left(\vec{m}_1, \vec{T}_{i j}\right) \cdot\left(\vec{m}_2, \vec{T}_{i j}\right)-$
# $=\left(\alpha \vec{m}_1+(1-\alpha) \vec{m}_2, \vec{T}_{i j}\right) \cdot\left(\alpha \vec{m}_2+(1-\alpha) \vec{m}_1, \vec{T}_{i j}\right)$
# Рассмотрим слагаемые при фиксированных $i \neq j$ (произвольных)
# Знаменатель $> 0$
# Числитель: $A_{ij} > 0$

# %% [markdown]
# $$N_{i j}=\left(\overrightarrow{m_1}, \overrightarrow{T_{i j}}\right) \cdot\left(\vec{m}_2, \vec{T}_{i j}\right)-$$
# $$-\left(\alpha\left(\vec{m}_1, \vec{T}_{i j}\right)+(1-\alpha) \cdot\left(\vec{m}_2, \vec{T}_{i j}\right)\right) \cdot$$
# $$\cdot\left(\alpha\left(\vec{m}_2, \vec T_{i j}\right)+(1-\alpha)\left(\vec{m}_1, \overrightarrow{T_{i j}}\right)\right)=$$
# $$=\left(\overrightarrow{m_1}, \overrightarrow{T_{i j}}\right) \cdot\left(\overrightarrow{m_2}, \overrightarrow{T_{i j}}\right)-$$
# $$-\alpha^2\left(\vec{m}_1, \vec{T} i\right) \cdot\left(\vec{m}_2, \vec T_{i j}\right)-$$
# $$-(1-\alpha) \cdot \alpha \cdot\left(\left(\overrightarrow{m_2}, \overrightarrow{T_i j}\right)^2+\left(\overrightarrow{m_1}, \vec T_{i j}\right)^2\right)-$$
# $$-(1-\alpha)^2 \cdot\left(\overrightarrow{m_1}, \overrightarrow{T_{i j}}\right) \cdot\left(\overrightarrow{m_2}, \overrightarrow{T_{i j}}\right)=$$

# %% [markdown]
# $$=\left(\vec{m}_1, \overrightarrow{T_{i j}}\right) \cdot\left(\vec{m}_2, \overrightarrow{T_{i j}}\right) \cdot\left(1-\alpha^2-(1-\alpha)^2\right)-$$
# $$-\underbrace{(1-\alpha) \cdot \alpha}_{\geq 0} \cdot(\underbrace{\left(\vec{m}_2, \vec{T}_i\right)^2+\left(\vec{m}_1, \vec T_{i j}\right)^2}_{\geq 0})=$$
# $$\Leftrightarrow\left(\vec{m}_1, \overrightarrow{T_{i j}}\right) \cdot\left(\overrightarrow{m_2}, \overrightarrow{T_{i j}}\right) \cdot\left(1-\alpha^2-(1-\alpha)^2\right)+x$$
# $$x \geq 0$$
# $$\left(\vec{m}_1, \vec{T}_{i j}\right) \cdot\left(\vec{m}_2, \overrightarrow{T_{i j}}\right) \cdot\left(1-\alpha^2-(1-\alpha)^2\right)^2=$$
# $$=\left(\vec{m}_1, \vec{T}_{i j}\right) \cdot\left(\vec{m}_2, \vec{T}_{i j}\right) \cdot\left(-2 \alpha^2+2 \alpha\right)=$$
# $$=\underbrace{\left(\vec{m}_1, \vec{T}_{i j}\right) \cdot\left(\vec{m}_2, \vec{T}_{i j}\right)}_{>0} \cdot(\underbrace{-2 \cdot \underbrace{\alpha \cdot(1-\alpha)}_{\geq 0})}_{\geq0})$$

# %% [markdown]
# В сумме каждое слагаемое $\leq 0 \Rightarrow$ вся сумма  тоже $\Rightarrow F(\vec{m})$ выпуклая функция.
# У выпуклой функции на выпуклом множестве существует только один глобальный минимум.

# %%
import random
import networkx as nx
import matplotlib.pyplot as plt
import scipy
import numpy as np
import math
from scipy.optimize import Bounds
from scipy.optimize import rosen, rosen_der, rosen_hess, rosen_hess_prod

class Route:
    
    def __init__(self, nodes, buses):
        self.nodes = nodes
        self.buses = buses
        
    def print(self, num):
        print("Route №", num, " ", [node.data for node in self.nodes], ", buses: ", self.buses)
        
    def insert_buses(self, count):
        self.buses = count

class Node:
  
    def __init__(self, data, indexloc = None):
        self.data = data
        self.index = indexloc
        
class Graph:
 
    @classmethod
    def create_from_nodes(self, nodes):
        return Graph(len(nodes), len(nodes), nodes)
 
  
    def __init__(self, row, col, nodes = None):
        self.nodesCount = row
        # Матрица смежности
        self.adj_mat = [[0] * col for _ in range(row)]
        # Матрица кратчайших путей
        self.dist_mat = [[0] * col for _ in range(row)]
        # Массив маршрутов
        self.routes = []
        # Матрица кол-ва автобусов i -> j
        self.buses_count_mat = [[0] * col for _ in range(row)]
        # Матрица времени ожидания i -> j
        self.waiting_time_mat = [[0] * col for _ in range(row)]
        # Матрица времени поездки i -> j
        self.travel_time_mat = [[0] * col for _ in range(row)]
        # Матрица Pi - доли пассажиров
        self.pi_mat = [[0] * col for _ in range(row)]
        # Матрица Pi, учитывающая реальное кол-во людей
        self.pi_adj_mat = [[0] * col for _ in range(row)]
        self.nodes = nodes
        # Вектор интенсивностей прихода пассажиров на остановки
        self.lambda_vec = [0] * col
        for i in range(len(self.nodes)):
            self.nodes[i].index = i
            self.lambda_vec[i] = random.randint(10, 50)
    
    # Обновление всех матриц, необходимых для вычисления времени
    def update_with_routes(self, routes):
        self.routes = routes
        self.buses_count_mat = [[0] * self.nodesCount for _ in range(self.nodesCount)]
        self.waiting_time_mat = [[0] * self.nodesCount for _ in range(self.nodesCount)]
        self.travel_time_mat = [[0] * self.nodesCount for _ in range(self.nodesCount)]
        self.pi_adj_mat = [[0] * self.nodesCount for _ in range(self.nodesCount)]
        self.fulfill_buses_count_mat()
        self.fulfill_waiting_time_mat(10)
        self.calculate_pi_adj_mat()
        self.update_waiting_time_mat()
        self.fulfill_travel_time_mat()

    # Вычисление суммарных временных затрат
    def calculate_total_time(self):
        total_waiting_time = self.calculate_total_waiting_time()
#         print(total_waiting_time)
        total_travel_time = self.calculate_total_travel_time()
#         print(total_travel_time)
        
        return total_waiting_time + total_travel_time
        
    
    def plot_graph(self):
        G=nx.Graph()
        elist = []
        for row in range(len(self.nodes)):
            for col in range(len(self.nodes)):
                if self.adj_mat[row][col] != 0:
                    elist.append((self.nodes[row].data, self.nodes[col].data, self.adj_mat[row][col]))
        G.add_weighted_edges_from(elist)
        pos = nx.circular_layout(G)
        nx.draw(G, pos, with_labels = True, node_size=1800)
#         nx.draw(G, with_labels = True)
        node_labels = nx.get_node_attributes(G, "label")
        nx.draw_networkx_labels(G, pos, labels=node_labels, font_size=15)
        edge_labels = nx.get_edge_attributes(G, "weight")
        print(edge_labels)
        nx.draw_networkx_edge_labels(G, pos, edge_labels=edge_labels)
        
        plt.show()
    
    # Генерация вектора интенсивностей прибытия пассажиров на каждую остановку
    # Аргументы randint - условно, минимальное и максимальное число возможной интенсивности прихода пассажиров
    def regen_lambda_vec(self):
        for i in range(len(self.lambda_vec)):
            self.lambda_vec[i] = random.randint(2, 20)
    
    # Генерация n чисел суммой total
    # Вспомогательный метод для определения долей пассажиров, следующих с одной остановки на другую
    # см. constrained_sum_sample_nonneg
    def constrained_sum_sample_pos(self, n, total):
        dividers = sorted(random.sample(range(1, total), n - 1))
        return [a - b for a, b in zip(dividers + [total], [0] + dividers)]
    
    # Генерация n неотрицательных чисел суммой total
    # На каждую остановку приходит 100% пассажиров
    # Нужно определить, какая часть хочет проследовать на каждую из остановок
    def constrained_sum_sample_nonneg(self, total):
        n = len(self.nodes) - 1
        return [x - 1 for x in self.constrained_sum_sample_pos(n, total + n)]
    
    # Генерация матрицы ||Pi||
    # По строкам - откуда, по столбцам - куда
    # Сумма чисел в строке = 1
    # Каждый ряд (row) показывает, какая доля пассажиров с остановки row едет на каждую из остановок (col)
    def generate_pi_mat(self):
        for row in range(len(self.nodes)):
            # 100 - потому что дальше будем переводить в проценты
            pi_row = self.constrained_sum_sample_nonneg(100)
            pi_row.insert(row, 0)
            for col in range(len(self.nodes)):
                self.pi_mat[row][col] = round(pi_row[col] / 100, 2)
                
    # Генерация матрицы ||Pi*||   
    # Скорректированная матрица Pi
    # Показывает конкретное число пассажиров, следующих с остановки row на остановку col
    # Учитывает интенсивность прихода пассажиров на каждую остановку
    def calculate_pi_adj_mat(self):
        for row in range(len(self.nodes)):
            for col in range(len(self.nodes)):
                self.pi_adj_mat[row][col] = round(self.pi_mat[row][col] * self.lambda_vec[row], 2)
 
    # Связывает node1 с node2
    # Обратите внимание, что ряд - источник, а столбец - назначение 
    # Обновлен для поддержки взвешенных ребер (поддержка алгоритма Дейкстры)
    def connect_dir(self, node1, node2, weight = 1):
        node1, node2 = self.get_index_from_node(node1), self.get_index_from_node(node2)
        self.adj_mat[node1][node2] = weight
  
    # Опциональный весовой аргумент для поддержки алгоритма Дейкстры
    def connect(self, node1, node2, weight = 1):
        self.connect_dir(node1, node2, weight)
        self.connect_dir(node2, node1, weight)
 
    # Получает ряд узла, отметить ненулевые объекты с их узлами в массиве self.nodes
    # Выбирает любые ненулевые элементы, оставляя массив узлов
    # которые являются connections_to (для ориентированного графа)
    # Возвращает значение: массив кортежей (узел, вес)
    def connections_from(self, node):
        node = self.get_index_from_node(node)
        return [(self.nodes[col_num], self.adj_mat[node][col_num]) for col_num in range(len(self.adj_mat[node])) if self.adj_mat[node][col_num] != 0]
 
    # Проводит матрицу к столбцу узлов
    # Проводит любые ненулевые элементы узлу данного индекса ряда
    # Выбирает только ненулевые элементы
    # Обратите внимание, что для неориентированного графа
    # используется connections_to ИЛИ connections_from
    # Возвращает значение: массив кортежей (узел, вес)
    def connections_to(self, node):
        node = self.get_index_from_node(node)
        column = [row[node] for row in self.adj_mat]
        return [(self.nodes[row_num], column[row_num]) for row_num in range(len(column)) if column[row_num] != 0]
     
  
    def print_adj_mat(self):
        for row in self.adj_mat:
            print(row)
  
    def node(self, index):
        return self.nodes[index]
    
  
    def remove_conn(self, node1, node2):
        self.remove_conn_dir(node1, node2)
        self.remove_conn_dir(node2, node1)
   
    # Убирает связь в направленной манере (nod1 к node2)
    # Может принять номер индекса ИЛИ объект узла
    def remove_conn_dir(self, node1, node2):
        node1, node2 = self.get_index_from_node(node1), self.get_index_from_node(node2)
        self.adj_mat[node1][node2] = 0   
  
    # Может пройти от node1 к node2
    def can_traverse_dir(self, node1, node2):
        node1, node2 = self.get_index_from_node(node1), self.get_index_from_node(node2)
        return self.adj_mat[node1][node2] != 0  
  
    def has_conn(self, node1, node2):
        return self.can_traverse_dir(node1, node2) or self.can_traverse_dir(node2, node1)
  
    def add_node(self,node):
        self.nodes.append(node)
        node.index = len(self.nodes) - 1
        for row in self.adj_mat:
            row.append(0)     
        self.adj_mat.append([0] * (len(self.adj_mat) + 1))
 
    # Получает вес, представленный перемещением от n1
    # к n2. Принимает номера индексов ИЛИ объекты узлов
    def get_weight(self, n1, n2):
        node1, node2 = self.get_index_from_node(n1), self.get_index_from_node(n2)
        return self.adj_mat[node1][node2]
  
    # Разрешает проводить узлы ИЛИ индексы узлов  
    def get_index_from_node(self, node):
        if not isinstance(node, Node) and not isinstance(node, int):
            raise ValueError("node must be an integer or a Node object")
        if isinstance(node, int):
            return node
        else:
            return node.index
        
    # Вычисление матрицы кратчайших расстояний
    def calculate_dist_mat(self):
        # Если захочется посмотреть значения, возвращаемые Дейкстрой:
        # for node in nodes:
        #     print([(weight, [n.data for n in node]) for (weight, node) in w_graph.dijkstra(node)])
        for node in nodes:
            for (weight, n) in w_graph.dijkstra(node):
                self.insert_dist(weight, n[0], n[-1])
        
    # Вставка кратчайшего расстояния i -> j в матрицу расстояний
    def insert_dist(self, dist, node_1, node_2):
        self.dist_mat[self.get_index_from_node(node_1)][self.get_index_from_node(node_2)] = dist
            
    # Заполнение матрицы автобусов, следующих i -> j
    def fulfill_buses_count_mat(self):
        for route in self.routes:
            for start in route.nodes:
                for finish in route.nodes:
                    self.insert_buses(start, finish, route.buses)
      
    # Кол-во автобусов, следующих от node_1 до node_2
    def insert_buses(self, node_1, node_2, count):
        start = self.get_index_from_node(node_1)
        finish = self.get_index_from_node(node_2)
        
        self.buses_count_mat[start][finish] += count
           
    # Заполнение матрицы времён ожидания
    def fulfill_waiting_time_mat(self, T):
        for row in range(len(self.nodes)):
            for col in range(len(self.nodes)):
                buses_count = self.buses_count_mat[row][col]
                if buses_count != 0:
                    self.waiting_time_mat[row][col] = round(T / buses_count, 2)
                else:
                    self.waiting_time_mat[row][col] = math.inf
    
    # Заполнение матрицы времён поездок
    def fulfill_travel_time_mat(self):
        for row in range(len(self.nodes)):
            for col in range(len(self.nodes)):
                self.travel_time_mat[row][col] = round(self.dist_mat[row][col] * self.pi_adj_mat[row][col], 2)
    
    # Пересчитывает время ожидания с учетом конкретного числа пассажиров на остановках
    def update_waiting_time_mat(self):
        for row in range(len(self.nodes)):
            for col in range(len(self.nodes)):
                self.waiting_time_mat[row][col] = round(self.pi_adj_mat[row][col] * self.waiting_time_mat[row][col], 2)
    
    # Сумма времен ожидания всех пассажиров на всех остановках
    def calculate_total_waiting_time(self):
        res = 0
        for row in range(len(self.nodes)):
            for col in range(len(self.nodes)):
                res += self.waiting_time_mat[row][col]
        return res
    
    # Сумма времен поездок всех пассажиров
    def calculate_total_travel_time(self):
        res = 0
        for row in range(len(self.nodes)):
            for col in range(len(self.nodes)):
                res += self.travel_time_mat[row][col]
        return res
    
    
    
    def print_buses_count_mat(self):
        print("Buses count mat:")
        for row in self.buses_count_mat:
            print(row)
        print()
    
    def print_dist_mat(self):
        print("Dist mat:")
        for row in self.dist_mat:
            print(row)
        print()
    
    def print_routes(self):
        print("Routes:")
        for route in self.routes:
            route.print()
        print()
    
    def print_waiting_time_mat(self):
        print("Waiting time mat:")
        for row in self.waiting_time_mat:
            print(row)
        print()
            
            
    def print_pi_mat(self):
        print("Pi mat")
        for row in self.pi_mat:
            print(row)
        print()
            
    def print_pi_adj_mat(self):
        print("Pi adj mat")
        for row in self.pi_adj_mat:
            print(row)
        print()
        
    # Дейкстра
    def dijkstra(self, node):
        # Получает индекс узла (или поддерживает передачу int)
        nodenum = self.get_index_from_node(node)
        # Заставляет массив отслеживать расстояние от одного до любого узла
        # в self.nodes. Инициализирует до бесконечности для всех узлов, кроме 
        # начального узла, сохраняет "путь", связанный с расстоянием. 
        # Индекс 0 = расстояние, индекс 1 = перескоки узла
        dist = [None] * len(self.nodes)
        for i in range(len(dist)):
            dist[i] = [float("inf")]
            dist[i].append([self.nodes[nodenum]])
        
        dist[nodenum][0] = 0
        # Добавляет в очередь все узлы графа
        # Отмечает целые числа в очереди, соответствующие индексам узла
        # локаций в массиве self.nodes 
        queue = [i for i in range(len(self.nodes))]
        # Набор увиденных на данный момент номеров 
        seen = set()
        while len(queue) > 0:
            # Получает узел в очереди, который еще не был рассмотрен
            # и который находится на кратчайшем расстоянии от источника
            min_dist = float("inf")
            min_node = None
            for n in queue: 
                if dist[n][0] < min_dist and n not in seen:
                    min_dist = dist[n][0]
                    min_node = n
            
            # Добавляет мин. расстояние узла до увиденного, убирает очередь
            queue.remove(min_node)
            seen.add(min_node)
            # Получает все следующие перескоки
            connections = self.connections_from(min_node)
            # Для каждой связи обновляет путь и полное расстояние от  
            # исходного узла, если полное расстояние меньше
            # чем текущее расстояние в массиве dist
            for (node, weight) in connections: 
                tot_dist = weight + min_dist
                if tot_dist < dist[node.index][0]:
                    dist[node.index][0] = tot_dist
                    dist[node.index][1] = list(dist[min_node][1])
                    dist[node.index][1].append(node)
        return dist

# %% [markdown]
# Считаем, что время ожидания атвобуса от остановки $i$ до остановки $j$ с учетом того, что $i$ и $j$ принадлежат каким - то автобусным маршрутам $P_{ij}$ будет равно $\frac{T}{\sum_{p \in P_{ij}}m_p}$, где $T$ некоторая универсальная для всех $i$ и $j$ временная константа, а определение $m_p$ дано. Далее ожидание врмени поездки тоже случайная величина, которая экспоненциально распределена с мат ожидаем пропорциональным расстоянию от $i$ до $j$

# %%
a = Node("A")
b = Node("B")
c = Node("C")
d = Node("D")
e = Node("E")
f = Node("F")
a1 = Node("A1")
b1 = Node("B1")
c1 = Node("C1")
d1 = Node("D1")
e1 = Node("E1")
f1 = Node("F1")
a2 = Node("A2")
b2 = Node("B2")
c2 = Node("C2")
d2 = Node("D2")
e2 = Node("E2")
f2 = Node("F2")

nodes = [a, b, c, d, e, f, a1, b1, c1, d1, e1, f1, a2, b2, c2, d2, e2, f2]

w_graph = Graph.create_from_nodes(nodes)

# Строим дороги
w_graph.connect(a, b, 5)
w_graph.connect(a, c, 10)
w_graph.connect(a, e, 4)
w_graph.connect(b, c, 2)
w_graph.connect(b, d, 4)
w_graph.connect(c, d, 7)
w_graph.connect(c, f, 10)
w_graph.connect(d, e, 3)
w_graph.connect(a, a1, 2)
w_graph.connect(a1, b1, 5)
w_graph.connect(a1, c1, 10)
w_graph.connect(a1, e1, 4)
w_graph.connect(b1, c1, 2)
w_graph.connect(b1, d1, 4)
w_graph.connect(c1, d1, 7)
w_graph.connect(c1, f1, 10)
w_graph.connect(d1, e1, 3)
w_graph.connect(a1, b2, 5)
w_graph.connect(a2, b2, 5)
w_graph.connect(a2, c2, 10)
w_graph.connect(a2, e2, 4)
w_graph.connect(b2, c2, 2)
w_graph.connect(b2, d2, 4)
w_graph.connect(c2, d2, 7)
w_graph.connect(c2, f2, 10)
w_graph.connect(d2, e2, 3)

# Вычисляем кратчайшие расстояния
w_graph.calculate_dist_mat()
# w_graph.print_dist_mat()


# Руками задаём маршруты, 2-й аргумент - кол-во автобусов на маршруте - предмет оптимизации
routes = []
routes.append(Route([a, b, c], 3))
routes.append(Route([a, c, f], 2))
routes.append(Route([d, b, c, f], 1))
routes.append(Route([f, c, a, e], 1))
routes.append(Route([d, e, a, c, b], 2))
routes.append(Route([a1, b1, c1], 3))
routes.append(Route([a1, c1, f1], 2))
routes.append(Route([d1, b1, c1, f1], 1))
routes.append(Route([f1, c1, a1, e1], 1))
routes.append(Route([d1, e1, a1, c1, b1], 2))
routes.append(Route([a2, b2, c2], 3))
routes.append(Route([a2, c2, f2], 2))
routes.append(Route([d2, b2, c2, f2], 1))
routes.append(Route([f2, c2, a2, e2], 1))
routes.append(Route([d2, e2, a2, c2, b2], 2))
routes.append(Route([a, b, c, d, e, f, a1, b1, c1, d1, e1, f1, a2, b2, c2, d2, e2, f2], 1))

w_graph.routes = routes

w_graph.fulfill_buses_count_mat()

# w_graph.print_routes()

# w_graph.print_buses_count_mat()

T = 10 # не влияет на результат после оптимизации, по идее))0)
w_graph.fulfill_waiting_time_mat(T)
# w_graph.print_waiting_time_mat()

w_graph.generate_pi_mat()
# w_graph.print_pi_mat()

w_graph.calculate_pi_adj_mat()
# print(w_graph.lambda_vec)
# w_graph.print_pi_adj_mat()

w_graph.plot_graph()
# Out:
# {('A', 'B'): 5, ('A', 'C'): 10, ('A', 'E'): 4, ('A', 'A1'): 2, ('B', 'C'): 2, ('B', 'D'): 4, ('C', 'D'): 7, ('C', 'F'): 10, ('E', 'D'): 3, ('A1', 'B1'): 5, ('A1', 'C1'): 10, ('A1', 'E1'): 4, ('A1', 'B2'): 5, ('B1', 'C1'): 2, ('B1', 'D1'): 4, ('C1', 'D1'): 7, ('C1', 'F1'): 10, ('E1', 'D1'): 3, ('B2', 'A2'): 5, ('B2', 'C2'): 2, ('B2', 'D2'): 4, ('A2', 'C2'): 10, ('A2', 'E2'): 4, ('C2', 'D2'): 7, ('C2', 'F2'): 10, ('E2', 'D2'): 3}

# %%
w_graph.generate_pi_mat()
w_graph.print_pi_mat()
# Out:
# Pi mat
# [0.0, 0.15, 0.23, 0.05, 0.03, 0.02, 0.07, 0.02, 0.06, 0.02, 0.08, 0.04, 0.03, 0.05, 0.02, 0.0, 0.02, 0.11]
# [0.01, 0.0, 0.1, 0.02, 0.0, 0.0, 0.09, 0.31, 0.01, 0.03, 0.01, 0.0, 0.04, 0.07, 0.0, 0.08, 0.05, 0.18]
# [0.07, 0.01, 0.0, 0.02, 0.02, 0.02, 0.0, 0.06, 0.0, 0.08, 0.22, 0.0, 0.18, 0.02, 0.04, 0.05, 0.17, 0.04]
# [0.02, 0.09, 0.1, 0.0, 0.03, 0.01, 0.08, 0.18, 0.0, 0.0, 0.01, 0.02, 0.22, 0.0, 0.04, 0.15, 0.02, 0.03]
# [0.06, 0.12, 0.02, 0.0, 0.0, 0.03, 0.02, 0.02, 0.0, 0.1, 0.12, 0.16, 0.05, 0.09, 0.07, 0.1, 0.03, 0.01]
# [0.02, 0.04, 0.04, 0.0, 0.1, 0.0, 0.03, 0.03, 0.27, 0.01, 0.03, 0.04, 0.08, 0.12, 0.02, 0.02, 0.01, 0.14]
# [0.07, 0.01, 0.06, 0.12, 0.03, 0.09, 0.0, 0.04, 0.04, 0.01, 0.08, 0.06, 0.0, 0.01, 0.27, 0.0, 0.1, 0.01]
# [0.08, 0.1, 0.0, 0.0, 0.05, 0.05, 0.08, 0.0, 0.0, 0.03, 0.14, 0.02, 0.0, 0.09, 0.16, 0.11, 0.03, 0.06]
# [0.06, 0.04, 0.24, 0.02, 0.01, 0.27, 0.06, 0.06, 0.0, 0.02, 0.01, 0.01, 0.05, 0.05, 0.02, 0.06, 0.01, 0.01]
# ...

# %%
w_graph.calculate_pi_adj_mat()
print(w_graph.lambda_vec)
w_graph.print_pi_adj_mat()
# Out:
# [23, 46, 36, 13, 48, 50, 45, 28, 26, 41, 48, 31, 24, 20, 17, 43, 29, 10]
# Pi adj mat
# [0.0, 3.45, 5.29, 1.15, 0.69, 0.46, 1.61, 0.46, 1.38, 0.46, 1.84, 0.92, 0.69, 1.15, 0.46, 0.0, 0.46, 2.53]
# [0.46, 0.0, 4.6, 0.92, 0.0, 0.0, 4.14, 14.26, 0.46, 1.38, 0.46, 0.0, 1.84, 3.22, 0.0, 3.68, 2.3, 8.28]
# [2.52, 0.36, 0.0, 0.72, 0.72, 0.72, 0.0, 2.16, 0.0, 2.88, 7.92, 0.0, 6.48, 0.72, 1.44, 1.8, 6.12, 1.44]
# [0.26, 1.17, 1.3, 0.0, 0.39, 0.13, 1.04, 2.34, 0.0, 0.0, 0.13, 0.26, 2.86, 0.0, 0.52, 1.95, 0.26, 0.39]
# [2.88, 5.76, 0.96, 0.0, 0.0, 1.44, 0.96, 0.96, 0.0, 4.8, 5.76, 7.68, 2.4, 4.32, 3.36, 4.8, 1.44, 0.48]
# [1.0, 2.0, 2.0, 0.0, 5.0, 0.0, 1.5, 1.5, 13.5, 0.5, 1.5, 2.0, 4.0, 6.0, 1.0, 1.0, 0.5, 7.0]
# [3.15, 0.45, 2.7, 5.4, 1.35, 4.05, 0.0, 1.8, 1.8, 0.45, 3.6, 2.7, 0.0, 0.45, 12.15, 0.0, 4.5, 0.45]
# [2.24, 2.8, 0.0, 0.0, 1.4, 1.4, 2.24, 0.0, 0.0, 0.84, 3.92, 0.56, 0.0, 2.52, 4.48, 3.08, 0.84, 1.68]
# ...

# %%
w_graph.update_waiting_time_mat()
w_graph.print_waiting_time_mat()
# Out:
# Waiting time mat:
# [0.0, 5.76, 5.87, 3.83, 1.72, 1.15, 16.1, 4.6, 13.8, 4.6, 18.4, 9.2, 6.9, 11.5, 4.6, 0.0, 4.6, 25.3]
# [0.77, 0.0, 6.58, 2.3, 0.0, 0.0, 41.4, 142.6, 4.6, 13.8, 4.6, 0.0, 18.4, 32.2, 0.0, 36.8, 23.0, 82.8]
# [2.8, 0.51, 0.0, 1.8, 1.8, 1.44, 0.0, 21.6, 0.0, 28.8, 79.2, 0.0, 64.8, 7.2, 14.4, 18.0, 61.2, 14.4]
# [0.87, 2.92, 3.25, 0.0, 1.3, 0.65, 10.4, 23.4, 0.0, 0.0, 1.3, 2.6, 28.6, 0.0, 5.2, 19.5, 2.6, 3.9]
# [7.2, 19.18, 2.4, 0.0, 0.0, 7.2, 9.6, 9.6, 0.0, 48.0, 57.6, 76.8, 24.0, 43.2, 33.6, 48.0, 14.4, 4.8]
# [2.5, 10.0, 4.0, 0.0, 25.0, 0.0, 15.0, 15.0, 135.0, 5.0, 15.0, 20.0, 40.0, 60.0, 10.0, 10.0, 5.0, 70.0]
# [31.5, 4.5, 27.0, 54.0, 13.5, 40.5, 0.0, 3.01, 2.0, 1.5, 9.0, 6.75, 0.0, 4.5, 121.5, 0.0, 45.0, 4.5]
# [22.4, 28.0, 0.0, 0.0, 14.0, 14.0, 3.74, 0.0, 0.0, 2.1, 13.05, 2.8, 0.0, 25.2, 44.8, 30.8, 8.4, 16.8]
# [15.6, 10.4, 62.4, 5.2, 2.6, 70.2, 1.73, 2.23, 0.0, 1.3, 0.65, 0.52, 13.0, 13.0, 5.2, 15.6, 2.6, 2.6]
# ...

# %%
total_waiting_time = w_graph.calculate_total_waiting_time()
print(total_waiting_time)
# Out:
# 4874.44

# %% [markdown]
# Теперь рассчитаем время поездки с остановки i на остановку j. Будем считать, что время поездки - случайная величина, имеющая экспоненциальное распределение, как скачки пуассона, не зависящее ни от чего. Мат ожидание случайной величины времени поездки i -> j будет пропорционально расстоянию от i до j. Это расстояние будем брать из матрицы кратчайших путей.

# %%
w_graph.fulfill_travel_time_mat()
w_graph.print_waiting_time_mat()
# Out:
# Waiting time mat:
# [0.0, 5.76, 5.87, 3.83, 1.72, 1.15, 16.1, 4.6, 13.8, 4.6, 18.4, 9.2, 6.9, 11.5, 4.6, 0.0, 4.6, 25.3]
# [0.77, 0.0, 6.58, 2.3, 0.0, 0.0, 41.4, 142.6, 4.6, 13.8, 4.6, 0.0, 18.4, 32.2, 0.0, 36.8, 23.0, 82.8]
# [2.8, 0.51, 0.0, 1.8, 1.8, 1.44, 0.0, 21.6, 0.0, 28.8, 79.2, 0.0, 64.8, 7.2, 14.4, 18.0, 61.2, 14.4]
# [0.87, 2.92, 3.25, 0.0, 1.3, 0.65, 10.4, 23.4, 0.0, 0.0, 1.3, 2.6, 28.6, 0.0, 5.2, 19.5, 2.6, 3.9]
# [7.2, 19.18, 2.4, 0.0, 0.0, 7.2, 9.6, 9.6, 0.0, 48.0, 57.6, 76.8, 24.0, 43.2, 33.6, 48.0, 14.4, 4.8]
# [2.5, 10.0, 4.0, 0.0, 25.0, 0.0, 15.0, 15.0, 135.0, 5.0, 15.0, 20.0, 40.0, 60.0, 10.0, 10.0, 5.0, 70.0]
# [31.5, 4.5, 27.0, 54.0, 13.5, 40.5, 0.0, 3.01, 2.0, 1.5, 9.0, 6.75, 0.0, 4.5, 121.5, 0.0, 45.0, 4.5]
# [22.4, 28.0, 0.0, 0.0, 14.0, 14.0, 3.74, 0.0, 0.0, 2.1, 13.05, 2.8, 0.0, 25.2, 44.8, 30.8, 8.4, 16.8]
# [15.6, 10.4, 62.4, 5.2, 2.6, 70.2, 1.73, 2.23, 0.0, 1.3, 0.65, 0.52, 13.0, 13.0, 5.2, 15.6, 2.6, 2.6]
# ...

# %%
total_travel_time = w_graph.calculate_total_travel_time()
print(total_travel_time)
# Out:
# 8628.78

# %% [markdown]
# Функция многих переменных, оптимум которой мы хотим найти
# Будем передавать её в метод optimize.minimize
# Параметр - вектор распределения автобусов по маршрутам
# При каждом новом значении вектора будем пересчитывать время ожидания - это непосредственно нахождение оптимума
# Для этого нужно не забыть пересчитать несколько матриц
# Также наложим ограничение в виде максимального кол-ва автобусов

# %%
max_buses_count = 300

def calculate_total_time_optimized(buses):
    # Обновляем кол-во автобусов на маршрутах
    for i in range(len(buses)):
        if buses[i] < 0:
            return math.inf
    if sum(buses) > max_buses_count:
        return math.inf
    for i in range(len(buses)):
        routes[i].insert_buses(buses[i])
#         routes[i].print()
    w_graph.update_with_routes(routes)
    return w_graph.calculate_total_time()

# %%
lb = [0] * len(routes)
ub = [max_buses_count] * len(routes)
bnds = list(zip(lb, ub))

buses_vector = [0.1] * len(routes)
    
result = scipy.optimize.fmin_slsqp(
    calculate_total_time_optimized,
    x0=buses_vector, 
    bounds = bnds,
    iprint = 0,
    epsilon = 0.9
)

for i in range(len(result)):
    routes[i].insert_buses(round(result[i], 5))
    routes[i].print(i + 1)
    
print()
print('Buses sum: ', sum(result))
# Out:
# Route № 1   ['A', 'B', 'C'] , buses:  15.9155
# Route № 2   ['A', 'C', 'F'] , buses:  11.06406
# Route № 3   ['D', 'B', 'C', 'F'] , buses:  6.52136
# Route № 4   ['F', 'C', 'A', 'E'] , buses:  4.42167
# Route № 5   ['D', 'E', 'A', 'C', 'B'] , buses:  6.11801
# Route № 6   ['A1', 'B1', 'C1'] , buses:  11.20922
# Route № 7   ['A1', 'C1', 'F1'] , buses:  11.0974
# Route № 8   ['D1', 'B1', 'C1', 'F1'] , buses:  0.40684
# Route № 9   ['F1', 'C1', 'A1', 'E1'] , buses:  6.67685
# Route № 10   ['D1', 'E1', 'A1', 'C1', 'B1'] , buses:  1.01239
# Route № 11   ['A2', 'B2', 'C2'] , buses:  16.18597
# Route № 12   ['A2', 'C2', 'F2'] , buses:  101.60317
# Route № 13   ['D2', 'B2', 'C2', 'F2'] , buses:  4.41912
# Route № 14   ['F2', 'C2', 'A2', 'E2'] , buses:  80.28443
# Route № 15   ['D2', 'E2', 'A2', 'C2', 'B2'] , buses:  4.24911
# Route № 16   ['A', 'B', 'C', 'D', 'E', 'F', 'A1', 'B1', 'C1', 'D1', 'E1', 'F1', 'A2', 'B2', 'C2', 'D2', 'E2', 'F2'] , buses:  18.04871
#
# ...
